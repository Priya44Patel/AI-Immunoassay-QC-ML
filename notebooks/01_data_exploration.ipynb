# %%
from src.preprocessing import read_plate, process_raw_folder, aggregate_replicates
import matplotlib.pyplot as plt
import seaborn as sns

df = process_raw_folder("data/raw")
df.head()
# Out:
#   Well Type Sample_ID  Concentration  Signal           Plate
# 0   A1  STD   STD_0.5            0.5    0.12  example_plate1
# 1   A2  STD   STD_0.5            0.5    0.11  example_plate1
# 2   A3  STD     STD_1            1.0    0.26  example_plate1
# 3   A4  STD     STD_1            1.0    0.27  example_plate1
# 4   A5  STD     STD_2            2.0    0.52  example_plate1

# %%
sns.boxplot(x="Type", y="Signal", data=df)
plt.show()
